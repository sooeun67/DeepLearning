# %%
#import fasttext
from keras.preprocessing.text import Tokenizer
from keras.preprocessing.sequence import pad_sequences
from sklearn.model_selection import train_test_split

import pandas as pd
import numpy as np

from scipy.spatial.distance import cosine 
#import pipeline.utils.db as db

# %%
job_title_table = db.execute(
    """
    SELECT DISTINCT TRIM(LOWER(job_title_test(job_title_cleaned))) 
    FROM cleaned_job_title.job_title_union_cleaned
    WHERE job_title_cleaned IS NOT NULL 
        AND job_title_cleaned not ilike '%and return%'
    """)

# %%
job_title_string = job_title_table['btrim'].tolist()

# %%
job_title_string[:10]
# Out:
# ['business owner bells nursery',
#  'counsel',
#  'coordnr',
#  'project managere',
#  'plumbing supply',
#  'employ serv technician iii',
#  'sos custodian ii',
#  'utility meter field operations',
#  'donated',
#  'health political consultant']

# %%
# random sampling from job_title_string list
from random import sample 

sample_1000 = sample(job_title_string,1000)
with open("sample_1000_strings.txt", "w") as output:
    for e in sample_1000:
        output.write(e + '\n')

# %%
sample_10000 = sample(job_title_string,10000)
sample_100000 = sample(job_title_string,100000)

with open("sample_10000_strings.txt", "w") as output:
    for e in sample_10000:
        output.write(e + '\n')

with open("sample_100000_strings.txt", "w") as output:
    for e in sample_100000:
        output.write(e + '\n')

# %%
# write entire strings into a text file.
with open("entire_strings.txt", "w") as output:
    for e in job_title_string:
        output.write(e + '\n')

# %% [markdown]
# ### Save a file as a train data

# %%
model = fasttext.train_unsupervised('sample_1000_strings.txt')

# %%
model_10000 = fasttext.train_unsupervised('sample_10000_strings.txt')

# %%
model_100000 = fasttext.train_unsupervised('sample_100000_strings.txt')

# %%
model_entire = fasttext.train_unsupervised('entire_strings.txt')

# %%
model_entire.words
# Out:
# ['</s>',
#  'director',
#  'and',
#  'president',
#  'manager',
#  'staff',
#  'assistant',
#  'vice',
#  'chief',
#  'senior',
#  'board',
#  'executive',
#  'for',
#  'officer',
#  'professor',
#  'transportation',
#  'representative',
#  'associate',
#  'services',
#  'university',
#  'health',
#  'sen',
#  'washington',
#  'department',
#  'dc',
#  'program',
#  'legislative',
#  'counsel',
#  'office',
#  'business',
#  'research',
#  'specialist',
#  'operations',
#  'house',
#  'ii',
#  'incorporated',
#  'affairs',
#  'supervisor',
#  'management',
#  'coordinator',
#  'development',
#  'chair',
#  'deputy',
#  'technician',
#  'policy',
#  'member',
#  'center',
#  'secretary',
#  'i',
#  'public',
#  'us',
#  'general',
#  'co',
#  'owner',
#  'committee',
#  'analyst',
#  'sales',
#  'consultant',
#  'on',
#  'attorney',
#  'group',
#  'retired',
#  'financial',
#  'senate',
#  'medical',
#  'school',
#  'engineer',
#  'administrative',
#  'advisor',
#  'senator',
#  'company',
#  'service',
#  'corporate',
#  'new',
#  'airfare',
#  'county',
#  'spec',
#  'law',
#  'llc',
#  'in',
#  'senators',
#  'medicine',
#  'division',
#  'resources',
#  'national',
#  'college',
#  'iii',
#  'per',
#  'marketing',
#  'diem',
#  'government',
#  'project',
#  'relations',
#  'human',
#  'communication',
#  'systems',
#  'technology',
#  'community',
#  'administrator',
#  'special',
#  'education',
#  'clerk',
#  'at',
#  'finance',
#  'head',
#  'global',
#  'support',
#  'care',
#  'energy',
#  'leg',
#  'engineering',
#  'international',
#  'real',
#  'estate',
#  'insurance',
#  'communications',
#  'lead',
#  'district',
#  'association',
#  'la',
#  'a',
#  'security',
#  'professional',
#  'science',
#  'planning',
#  'clinical',
#  'system',
#  'environmental',
#  'institute',
#  'amp',
#  'principal',
#  'safety',
#  'regional',
#  'leader',
#  'it',
#  'prof',
#  'information',
#  'ohio',
#  'teacher',
#  'dean',
#  'american',
#  'former',
#  'history',
#  'tax',
#  'york',
#  'self',
#  'consulting',
#  'legal',
#  'court',
#  'north',
#  'compliance',
#  'bank',
#  'aide',
#  'construction',
#  'congressman',
#  'council',
#  'dep',
#  'data',
#  'partner',
#  'm',
#  'managing',
#  'worker',
#  'associates',
#  'commissioner',
#  'commercial',
#  'hospital',
#  'strategy',
#  'scientist',
#  'john',
#  'cmte',
#  's',
#  'accounting',
#  'ld',
#  'social',
#  'r',
#  'technical',
#  'administration',
#  'cos',
#  'corporation',
#  'water',
#  'commerce',
#  'field',
#  'quality',
#  'sciences',
#  'control',
#  'home',
#  'solutions',
#  'intern',
#  'media',
#  'operator',
#  'agency',
#  'texas',
#  'foundation',
#  'c',
#  'california',
#  'iv',
#  'agent',
#  'training',
#  'student',
#  'ed',
#  'physician',
#  'd',
#  'univ',
#  'design',
#  'operating',
#  'md',
#  'federal',
#  'st',
#  'e',
#  'b',
#  'studies',
#  'labor',
#  'supply',
#  'strategic',
#  'as',
#  'j',
#  'maintenance',
#  'family',
#  'network',
#  'risk',
#  'customer',
#  'instructor',
#  'nurse',
#  'programs',
#  'auto',
#  'product',
#  'banking',
#  'employed',
#  'fire',
#  'subcommittee',
#  'retail',
#  'police',
#  'healthcare',
#  'gas',
#  'investment',
#  'food',
#  'south',
#  'non',
#  'property',
#  'boston',
#  'political',
#  'equipment',
#  'hartford',
#  'laboratory',
#  'arts',
#  'park',
#  'air',
#  'west',
#  'nursing',
#  'employee',
#  'counselor',
#  'prog',
#  'chicago',
#  'rock',
#  'digital',
#  'h',
#  'treasurer',
#  'judge',
#  'lab',
#  'oil',
#  'trade',
#  'investigator',
#  'acting',
#  'med',
#  'independent',
#  'united',
#  'land',
#  'correspondent',
#  'budget',
#  'san',
#  'capital',
#  'voucher',
#  'continued',
#  'resource',
#  'inspector',
#  'regulatory',
#  'art',
#  'follows',
#  'cong',
#  'commission',
#  'fellow',
#  'area',
#  'plant',
#  'cancer',
#  'natural',
#  'industry',
#  'projects',
#  'republican',
#  'production',
#  'facilities',
#  'l',
#  'info',
#  'housing',
#  'ny',
#  'computer',
#  'marine',
#  'llp',
#  'va',
#  'press',
#  'america',
#  'region',
#  'little',
#  'majority',
#  'ca',
#  'outreach',
#  'developer',
#  'manufacturing',
#  'library',
#  'liaison',
#  'distinguished',
#  'software',
#  'credit',
#  'defense',
#  'consumer',
#  'providence',
#  'lake',
#  'justice',
#  'economic',
#  'interim',
#  'portland',
#  'team',
#  'museum',
#  'schools',
#  'investor',
#  'firm',
#  'coach',
#  'union',
#  'products',
#  'v',
#  'market',
#  'reg',
#  'local',
#  'unit',
#  'ma',
#  'florida',
#  'p',
#  'account',
#  'academic',
#  'surgery',
#  'agriculture',
#  'central',
#  'biology',
#  'off',
#  'environment',
#  'power',
#  'planner',
#  'building',
#  'writer',
#  'designer',
#  'auditor',
#  'veterans',
#  'accounts',
#  'contractor',
#  'ex',
#  'analysis',
#  'east',
#  'civil',
#  'robert',
#  'white',
#  'facility',
#  'whip',
#  'ag',
#  'emergency',
#  'serv',
#  'farm',
#  'superintendent',
#  'mo',
#  'founder',
#  'child',
#  'columbus',
#  't',
#  'enterprise',
#  'section',
#  'appropriations',
#  'manchester',
#  'controller',
#  'workforce',
#  'smith',
#  'cleveland',
#  'pac',
#  'educator',
#  'maint',
#  'states',
#  'branch',
#  'process',
#  'small',
#  'limited',
#  'faculty',
#  'industrial',
#  'english',
#  'pediatrics',
#  'kansas',
#  'contract',
#  'res',
#  'adv',
#  'claims',
#  'carolina',
#  'private',
#  'tx',
#  'assist',
#  'producer',
#  'johnson',
#  'childrens',
#  'emeritus',
#  'revenue',
#  'or',
#  'external',
#  'g',
#  'tupelo',
#  'protection',
#  'george',
#  'advocacy',
#  'store',
#  'bureau',
#  'congressional',
#  'innovation',
#  'fl',
#  'examiner',
#  'mental',
#  'mechanic',
#  'conservation',
#  'u',
#  'architect',
#  'virginia',
#  'ctr',
#  'first',
#  'life',
#  'k',
#  'editor',
#  'rental',
#  'broker',
#  'oncology',
#  'philadelphia',
#  'loan',
#  'military',
#  'fare',
#  'ses',
#  'society',
#  'partners',
#  'hon',
#  'mgt',
#  'music',
#  'supt',
#  'pharmacy',
#  'client',
#  'judiciary',
#  'time',
#  'utility',
#  'force',
#  'technologies',
#  'internal',
#  'advocate',
#  'case',
#  'train',
#  'tom',
#  'interdepartmental',
#  'bill',
#  'learning',
#  'following',
#  'practice',
#  'materials',
#  'electric',
#  'western',
#  'minority',
#  'youth',
#  'benefits',
#  'southern',
#  'audit',
#  'comp',
#  'pa',
#  'employment',
#  'gov',
#  'lpa',
#  'jim',
#  'accountant',
#  'molecular',
#  'organization',
#  'adjunct',
#  'infrastructure',
#  'expenses',
#  'fort',
#  'speaker',
#  'falls',
#  'atlanta',
#  'w',
#  'indianapolis',
#  'valley',
#  'clinic',
#  'electrical',
#  'graduate',
#  'subsequent',
#  'asset',
#  'com',
#  'distribution',
#  'scientific',
#  'grant',
#  'profit',
#  'previous',
#  'trust',
#  'adm',
#  'personnel',
#  'advanced',
#  'enforcement',
#  'work',
#  'michigan',
#  'pathology',
#  'driver',
#  'corinth',
#  'records',
#  'lincoln',
#  'brown',
#  'correctional',
#  'ct',
#  'bob',
#  'investments',
#  'maj',
#  'legis',
#  'prevention',
#  'wildlife',
#  'shop',
#  'foreign',
#  'performance',
#  'logistics',
#  'james',
#  'dist',
#  'chain',
#  'los',
#  'wa',
#  'pro',
#  'approps',
#  'therapist',
#  'nuclear',
#  'army',
#  'chemical',
#  'career',
#  'beach',
#  'oklahoma',
#  'psychiatry',
#  'columbia',
#  'repair',
#  'fund',
#  'works',
#  'springs',
#  'trans',
#  'advisory',
#  'hill',
#  'ways',
#  'des',
#  'leadership',
#  'dpty',
#  'mayor',
#  'fiscal',
#  'river',
#  'denver',
#  'realty',
#  'endowed',
#  'title',
#  'thomas',
#  'physical',
#  'sup',
#  'held',
#  'part',
#  'mike',
#  'pt',
#  'las',
#  'illinois',
#  'treasury',
#  'animal',
#  'artist',
#  'cincinnati',
#  'springfield',
#  'patient',
#  'industries',
#  'high',
#  'aid',
#  'dental',
#  'review',
#  'analytics',
#  'reform',
#  'motor',
#  'prgm',
#  'th',
#  'librarian',
#  'angeles',
#  'volunteer',
#  'ins',
#  'newark',
#  'homeland',
#  'temporary',
#  'richard',
#  'procurement',
#  'dealer',
#  'help',
#  'mortgage',
#  'site',
#  'forest',
#  'representatives',
#  'recreation',
#  'f',
#  'green',
#  'womens',
#  'pittsburgh',
#  'lawyer',
#  'epidemiology',
#  'william',
#  'rel',
#  'louis',
#  'seattle',
#  'indian',
#  'delivery',
#  'educational',
#  'traffic',
#  'means',
#  'miami',
#  'democratic',
#  'representing',
#  'salt',
#  'campaign',
#  'provider',
#  'colorado',
#  'il',
#  'alliance',
#  'disability',
#  'vehicle',
#  'cpa',
#  'ambassador',
#  'grants',
#  'not',
#  'paul',
#  'events',
#  'inst',
#  'pc',
#  'mark',
#  'cofounder',
#  'treatment',
#  'baltimore',
#  'processing',
#  'oversight',
#  'pediatric',
#  'supervising',
#  'albany',
#  'aviation',
#  'jackson',
#  'chemistry',
#  'sci',
#  'prin',
#  'detroit',
#  'equip',
#  'tn',
#  'nc',
#  'rehab',
#  'car',
#  'activities',
#  'saint',
#  're',
#  'incidentals',
#  'moines',
#  'campus',
#  'with',
#  'trainer',
#  'michael',
#  'web',
#  'automotive',
#  'portsmouth',
#  'burlington',
#  'vegas',
#  'ac',
#  'maryland',
#  'austin',
#  'governmental',
#  'parks',
#  'plan',
#  'drug',
#  'corr',
#  'aging',
#  'conference',
#  'genetics',
#  'biomedical',
#  'retreat',
#  'ga',
#  'rehabilitation',
#  'houston',
#  'engagement',
#  'behavioral',
#  'oxford',
#  'floor',
#  'forensic',
#  'pr',
#  'registered',
#  'certified',
#  'long',
#  'rights',
#  'sp',
#  'charles',
#  'jr',
#  'line',
#  'op',
#  'enterprises',
#  'jeffersonville',
#  'officio',
#  'de',
#  'mobile',
#  'ofc',
#  'action',
#  'candidate',
#  'francisco',
#  'radiology',
#  'intelligence',
#  'memphis',
#  'residential',
#  'prod',
#  'foreman',
#  'davis',
#  'lending',
#  'rogers',
#  'airport',
#  'trainee',
#  'rn',
#  'georgetown',
#  'ad',
#  'psychology',
#  'georgia',
#  'agricultural',
#  'lobbyist',
#  'researcher',
#  'assurance',
#  'haven',
#  'talent',
#  'highway',
#  'anchorage',
#  'camp',
#  'mem',
#  'waste',
#  'criminal',
#  'space',
#  'academy',
#  'pennsylvania',
#  'gm',
#  'properties',
#  'restaurant',
#  'fish',
#  'usa',
#  'arizona',
#  'imaging',
#  'experience',
#  'farmer',
#  'wilmington',
#  'governor',
#  'licensed',
#  'sheriff',
#  'pacific',
#  'manhattan',
#  'reno',
#  'educ',
#  'urban',
#  'sports',
#  'tutor',
#  'bd',
#  'david',
#  'massachusetts',
#  'event',
#  'physics',
#  'economics',
#  'scheduler',
#  'strategies',
#  'wholesale',
#  'markets',
#  'diversity',
#  'lc',
#  'psychologist',
#  'dover',
#  'programmer',
#  'mechanical',
#  'lowell',
#  'miller',
#  'sch',
#  'initiatives',
#  'grand',
#  'core',
#  'disease',
#  'consultants',
#  'captain',
#  'retirement',
#  'integration',
#  'realtor',
#  'nutrition',
#  'club',
#  'cross',
#  'workers',
#  'fleet',
#  'radio',
#  'reporting',
#  'personal',
#  'strategist',
#  'el',
#  'minneapolis',
#  'madison',
#  'film',
#  'creative',
#  'provost',
#  'master',
#  'utilities',
#  'mexico',
#  'santa',
#  'none',
#  'mech',
#  'dot',
#  'orleans',
#  'oh',
#  'around',
#  'port',
#  'pilot',
#  'joint',
#  'application',
#  'blunt',
#  'trustee',
#  'rd',
#  'appeals',
#  'purchasing',
#  'scholar',
#  'petroleum',
#  'int',
#  'cnsl',
#  'esg',
#  'anthropology',
#  'schumer',
#  'machine',
#  'allentown',
#  'harvard',
#  'rochester',
#  'portfolio',
#  'advertising',
#  'charleston',
#  'iowa',
#  'n',
#  'under',
#  'therapy',
#  'dhb',
#  'lecturer',
#  'reserve',
#  'neurology',
#  'authority',
#  'humanities',
#  'lee',
#  'parking',
#  'cust',
#  'evaluation',
#  'direct',
#  'supervisory',
#  'content',
#  'is',
#  'access',
#  'min',
#  'lansing',
#  'occupational',
#  'curator',
#  'party',
#  'aff',
#  'augusta',
#  'chancellor',
#  'kentucky',
#  'mount',
#  'contracts',
#  'mn',
#  'mi',
#  'collections',
#  'wisconsin',
#  'island',
#  'interior',
#  'sustainability',
#  'author',
#  'payroll',
#  'companies',
#  'bend',
#  'ofcr',
#  'farms',
#  'by',
#  'travel',
#  'assessment',
#  'ret',
#  'corrections',
#  'secy',
#  'truck',
#  'dayton',
#  'coor',
#  'orlando',
#  'resident',
#  'licensing',
#  'svs',
#  'advisors',
#  'northern',
#  'usda',
#  'rural',
#  'constituent',
#  'technologist',
#  'brand',
#  'applications',
#  'mary',
#  'municipal',
#  'milwaukee',
#  'supplier',
#  'al',
#  'minnesota',
#  'immunology',
#  'surgeon',
#  'congress',
#  'major',
#  'fayetteville',
#  'operation',
#  'man',
#  'forestry',
#  'pharmacology',
#  'o',
#  'centers',
#  'gulf',
#  'mid',
#  'pol',
#  'cell',
#  'biostatistics',
#  'great',
#  'improvement',
#  'task',
#  'wealth',
#  'sc',
#  'informatics',
#  'juvenile',
#  'young',
#  'conway',
#  'early',
#  'ethics',
#  'economist',
#  'funeral',
#  'doe',
#  'video',
#  'elections',
#  'americas',
#  'oregon',
#  'landscape',
#  'banker',
#  'frank',
#  'recovery',
#  'charlotte',
#  'cantor',
#  'church',
#  'tribal',
#  'metal',
#  'telecommunications',
#  'lieutenant',
#  'kennedy',
#  'spclt',
#  'drilling',
#  'assistance',
#  'rules',
#  'sa',
#  'funding',
#  'joe',
#  'const',
#  'scott',
#  'alaska',
#  'trades',
#  'distributor',
#  'billing',
#  'ch',
#  'dr',
#  'electronic',
#  'greenwich',
#  'institutional',
#  'eastern',
#  'point',
#  'junction',
#  'compensation',
#  'indiana',
#  'omaha',
#  'domestic',
#  'na',
#  'tv',
#  'parts',
#  'visiting',
#  'station',
#  'appraiser',
#  'warehouse',
#  'bay',
#  'cio',
#  'graphic',
#  'doctor',
#  'jud',
#  'biologist',
#  'judicial',
#  'partnerships',
#  'term',
#  'entertainment',
#  'fac',
#  'infectious',
#  'physiology',
#  'bridge',
#  'chamber',
#  'riverside',
#  'online',
#  'pharmaceutical',
#  'hopkins',
#  ...]

# %%
model_entire.get_word_vector("director")
# Out:
# array([ 0.28254294,  0.11425452,  0.64991885, -0.33367488,  0.14480731,
#         0.32661965,  0.11356138, -0.52821726, -0.02379922,  0.59376067,
#         0.3995769 , -0.5220222 , -0.32375932, -0.00671822, -0.29120645,
#        -0.13525972,  0.15468091,  0.30402485, -0.2705321 , -0.30351445,
#         0.27237853,  0.02972574, -0.17408799, -0.7527171 ,  0.20219615,
#        -0.12387756, -0.03159215,  0.03329852, -0.22355215, -0.39831924,
#        -0.21019736,  0.16828498, -0.29907453, -0.26985803, -0.38436836,
#        -0.4098281 , -0.4076704 , -0.17722748, -0.01399893, -0.20677973,
#        -0.2315893 , -0.17358483,  0.39348665,  0.14055163,  0.00293521,
#        -0.10166384, -0.9690602 , -0.05606403, -0.07040814,  0.754362  ,
#        -0.7543453 ,  0.28471643, -0.25636464,  0.4225403 , -0.33933416,
#         0.18015964,  0.00380394,  0.04054176,  0.2754836 ,  0.07592319,
#         0.19646785,  0.2597035 ,  0.30725324, -0.3422433 , -0.33064035,
#         0.16749115,  0.23598629, -0.17007227,  0.04245004, -0.18653212,
#        -0.35422876, -0.3373413 , -0.29838052, -0.23541117,  0.22478679,
#         0.06263195,  0.09379259,  0.42850372, -0.02696201, -0.358361  ,
#        -0.08378213,  0.41923422, -0.2179186 ,  0.10418607, -0.33020607,
#        -0.52210474,  0.09350533,  0.49000505,  0.23084337, -0.5447357 ,
#         0.13652056, -0.07181176,  0.24473569, -0.8996398 ,  0.42635185,
#        -0.20525672,  0.3019027 ,  0.48795548, -0.08988176,  0.6857001 ],
#       dtype=float32)

# %%
# this library also handles unknown word. Sub-word(https://www.google.com/search?q=what+is+sub+word+embedding+post&tbm=isch&ved=2ahUKEwizs6SYyfjnAhVQON8KHb0zBKIQ2-cCegQIABAA&oq=what+is+sub+word+embedding+post&gs_l=img.3...177958.178505..182456...0.0..0.271.1324.2-5......0....1..gws-wiz-img.e-e7aWYhjIE&ei=6EtbXrOfMdDw_Aa955CQCg&bih=897&biw=1920#imgrc=pyWK-uyUK6Hr6M)
#based 이기 때문에 typo 에 robust 한 장점이 있다.
model_entire.get_word_vector("diiirecctorr")
# Out:
# array([-0.07641841, -0.01019991,  0.14039214, -0.10801964,  0.13926701,
#         0.06459436,  0.26529774, -0.13913338,  0.16443087,  0.2480375 ,
#        -0.02834942, -0.11340211, -0.038286  , -0.05720075, -0.09654281,
#        -0.08254253, -0.06039055,  0.13004442, -0.173125  , -0.07439607,
#        -0.12404697,  0.06603786, -0.23672588, -0.4343378 ,  0.06400086,
#        -0.04939949, -0.17333011,  0.0007918 , -0.14419292, -0.00510129,
#        -0.37103295, -0.09441509, -0.07734393, -0.17991202, -0.16950858,
#        -0.19071306,  0.09021781, -0.11489707,  0.01149432,  0.10678458,
#        -0.0023703 , -0.03798649,  0.15646948,  0.0333753 , -0.0723674 ,
#         0.08042976, -0.16062222,  0.03944276,  0.00659632,  0.07281209,
#        -0.19456372, -0.17296451, -0.11634398,  0.08607875,  0.07862102,
#        -0.00053292,  0.0667675 ,  0.23368883,  0.1962292 ,  0.40421188,
#         0.09589522,  0.3046587 ,  0.27409095,  0.01158673, -0.22397102,
#         0.00902798, -0.17460425,  0.0174568 ,  0.15116252, -0.12199395,
#        -0.23856726, -0.00995984, -0.12081181,  0.06647338,  0.13358344,
#        -0.03440291,  0.06401423,  0.14945646,  0.12955011, -0.21197891,
#        -0.12509055,  0.12374341, -0.10653441, -0.17357597, -0.13246168,
#        -0.21606784,  0.07795559,  0.16177315, -0.00246838, -0.1729438 ,
#         0.07675429,  0.04519816,  0.21530774, -0.30470425,  0.21466893,
#         0.02175168,  0.17527908,  0.3436827 , -0.05523428,  0.28908223],
#       dtype=float32)

# %%
titles = pd.read_csv('FINAL_fixed_soc_codes_01182018.csv')
cat = pd.read_csv('job classifications - job_title_categorization.csv')
cat['soc_code'] = cat['bls_job_type'].astype(str) + '-' + cat['bls_job_subtype'].astype(str)

df = titles.merge(cat, how='inner', left_on='2018_soc_code', right_on='soc_code')
df['job_title'] = df['soc_direct_match_title'].str.lower().str.strip()
df['label'] = df['job_level']
df = df.dropna()
df.head(n=20)
# Out:
#    2018_soc_code         soc_title            soc_direct_match_title  \
# 0        11-1011  Chief Executives                           Admiral
# 1        11-1011  Chief Executives           CHIEF EXECUTIVE OFFICER
# 2        11-1011  Chief Executives           Chief Executive Officer
# 3        11-1011  Chief Executives           Chief Financial Officer
# 4        11-1011  Chief Executives           Chief Operating Officer
# 5        11-1011  Chief Executives      Chief Sustainability Officer
# 6        11-1011  Chief Executives  Commissioner of Internal Revenue
# 7        11-1011  Chief Executives           CHIEF OPERATING OFFICER
# 8        11-1011  Chief Executives               County Commissioner
# 9        11-1011  Chief Executives      Government Service Executive
# 10       11-1011  Chief Executives                          Governor
# 11       11-1011  Chief Executives                             Mayor
# 12       11-1011  Chief Executives             School Superintendent
# 13       11-1011  Chief Executives              University President
# 14       11-1011  Chief Executives                    Chief of Staff
# 15       11-1011  Chief Executives                           Trustee
# 16       11-1011  Chief Executives                    Vice President
# 17       11-1011  Chief Executives                          Chairman
# 18       11-1011  Chief Executives                     Vice Chairman
# 19       11-1011  Chief Executives                           Partner
#
#     bls_job_type  bls_job_subtype bls_job_subtype_name        job_level  \
# 0             11             1011     Chief Executives  chief_executive
# 1             11             1011     Chief Executives  chief_executive
# 2             11             1011     Chief Executives  chief_executive
# 3             11             1011     Chief Executives  chief_executive
# 4             11             1011     Chief Executives  chief_executive
# 5             11             1011     Chief Executives  chief_executive
# 6             11             1011     Chief Executives  chief_executive
# 7             11             1011     Chief Executives  chief_executive
# 8             11             1011     Chief Executives  chief_executive
# 9             11             1011     Chief Executives  chief_executive
# 10            11             1011     Chief Executives  chief_executive
# 11            11             1011     Chief Executives  chief_executive
# 12            11             1011     Chief Executives  chief_executive
# 13            11             1011     Chief Executives  chief_executive
# 14            11             1011     Chief Executives  chief_executive
# 15            11             1011     Chief Executives  chief_executive
# 16            11             1011     Chief Executives  chief_executive
# 17            11             1011     Chief Executives  chief_executive
# 18            11             1011     Chief Executives  chief_executive
# 19            11             1011     Chief Executives  chief_executive
#
#    soc_code                         job_title            label
# 0   11-1011                           admiral  chief_executive
# 1   11-1011           chief executive officer  chief_executive
# 2   11-1011           chief executive officer  chief_executive
# 3   11-1011           chief financial officer  chief_executive
# 4   11-1011           chief operating officer  chief_executive
# 5   11-1011      chief sustainability officer  chief_executive
# 6   11-1011  commissioner of internal revenue  chief_executive
# 7   11-1011           chief operating officer  chief_executive
# 8   11-1011               county commissioner  chief_executive
# 9   11-1011      government service executive  chief_executive
# 10  11-1011                          governor  chief_executive
# 11  11-1011                             mayor  chief_executive
# 12  11-1011             school superintendent  chief_executive
# 13  11-1011              university president  chief_executive
# 14  11-1011                    chief of staff  chief_executive
# 15  11-1011                           trustee  chief_executive
# 16  11-1011                    vice president  chief_executive
# 17  11-1011                          chairman  chief_executive
# 18  11-1011                     vice chairman  chief_executive
# 19  11-1011                           partner  chief_executive

# %%
texts = df['job_title'].tolist()

# %%
X = np.array([model_entire.get_sentence_vector(e) for e in texts]) # vectorize each element in list

X = np.expand_dims(X, axis=2)  # reshape  to 3D

# %%
X.shape
# Out:
# (7440, 100, 1)

# %%
y = pd.get_dummies(df['label'], drop_first=False)
y.shape
# Out:
# (7440, 5)

# %%
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.1, random_state=1)

# %%
Model

# %%
from keras.models import Sequential
from keras.layers import Input, Embedding, Dense, Dropout, Conv1D, MaxPooling1D, GlobalMaxPooling1D

window_size = 3
drop_out = 0.2
input_shape=(100,1)


model = Sequential()

#model.add(Embedding(max_words, 64, input_length=500))
# dilation_rate = 2 represents mid-layers 이 두 배로 펼쳐진다.. 
model.add(Conv1D(256, kernel_size=window_size, input_shape = input_shape, activation='relu', dilation_rate = 2))
model.add(Dropout(0.2))
model.add(MaxPooling1D(window_size))
model.add(Conv1D(512, window_size, activation='relu', dilation_rate = 2))
model.add(Dropout(0.2))
model.add(MaxPooling1D(window_size))
model.add(GlobalMaxPooling1D())
model.add(Dropout(0.2))
model.add(Dense(128, activation='relu'))
model.add(Dropout(0.2))
model.add(Dense(y.shape[1], activation='softmax'))
model.compile(optimizer='adam',
              loss='categorical_crossentropy',
              metrics=['acc'])
model.summary()
# Out:
# Model: "sequential_1"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# conv1d_1 (Conv1D)            (None, 96, 256)           1024
# _________________________________________________________________
# dropout_1 (Dropout)          (None, 96, 256)           0
# _________________________________________________________________
# max_pooling1d_1 (MaxPooling1 (None, 32, 256)           0
# _________________________________________________________________
# conv1d_2 (Conv1D)            (None, 28, 512)           393728
# _________________________________________________________________
# dropout_2 (Dropout)          (None, 28, 512)           0
# _________________________________________________________________
# max_pooling1d_2 (MaxPooling1 (None, 9, 512)            0
# _________________________________________________________________
# global_max_pooling1d_1 (Glob (None, 512)               0
# _________________________________________________________________
# dropout_3 (Dropout)          (None, 512)               0
# _________________________________________________________________
# dense_1 (Dense)              (None, 128)               65664
# _________________________________________________________________
# dropout_4 (Dropout)          (None, 128)               0
# _________________________________________________________________
# dense_2 (Dense)              (None, 5)                 645
# =================================================================
# Total params: 461,061
# Trainable params: 461,061
# Non-trainable params: 0
# _________________________________________________________________

# %%
import keras

batch_size = 32
epochs = 50

callback_list = [
    keras.callbacks.EarlyStopping(
        monitor='val_loss',
        mode='min',
        patience=10
    ),
    
#     keras.callbacks.TensorBoard(
#         log_dir='log_dir_m1',
#         histogram_freq=1,
#         embeddings_freq=1,
#     ),

    keras.callbacks.ModelCheckpoint(
        monitor='val_loss',
        save_best_only=True,
        filepath='job_classification.h5',
    ),

    keras.callbacks.ReduceLROnPlateau(
        patience=10,
        factor=0.1,
    )
]

# %%
history = model.fit(X_train, y_train,
          batch_size=batch_size,
          epochs=epochs,
          verbose=1,
          validation_split=0.1,
          callbacks=callback_list)
# Out:
# Train on 6026 samples, validate on 670 samples
# Epoch 1/50
# 6026/6026 [==============================] - 14s 2ms/step - loss: 0.9929 - acc: 0.6917 - val_loss: 0.9675 - val_acc: 0.6866
# Epoch 2/50
# 6026/6026 [==============================] - 12s 2ms/step - loss: 0.9001 - acc: 0.6958 - val_loss: 0.8330 - val_acc: 0.6866
# Epoch 3/50
# 6026/6026 [==============================] - 13s 2ms/step - loss: 0.8095 - acc: 0.7113 - val_loss: 0.7382 - val_acc: 0.7224
# Epoch 4/50
# 6026/6026 [==============================] - 13s 2ms/step - loss: 0.7195 - acc: 0.7458 - val_loss: 0.6698 - val_acc: 0.7507
# Epoch 5/50
# 6026/6026 [==============================] - 13s 2ms/step - loss: 0.6616 - acc: 0.7662 - val_loss: 0.6894 - val_acc: 0.7731
# Epoch 6/50
# 6026/6026 [==============================] - 13s 2ms/step - loss: 0.6249 - acc: 0.7821 - val_loss: 0.6131 - val_acc: 0.7821
# Epoch 7/50
# 6026/6026 [==============================] - 12s 2ms/step - loss: 0.6033 - acc: 0.7849 - val_loss: 0.6136 - val_acc: 0.7821
# Epoch 8/50
# 6026/6026 [==============================] - 12s 2ms/step - loss: 0.5759 - acc: 0.8004 - val_loss: 0.5823 - val_acc: 0.7836
# Epoch 9/50
# 6026/6026 [==============================] - 12s 2ms/step - loss: 0.5450 - acc: 0.8070 - val_loss: 0.5761 - val_acc: 0.7910
# Epoch 10/50
# 6026/6026 [==============================] - 12s 2ms/step - loss: 0.5307 - acc: 0.8140 - val_loss: 0.5507 - val_acc: 0.7985
# Epoch 11/50
# 6026/6026 [==============================] - 12s 2ms/step - loss: 0.5240 - acc: 0.8186 - val_loss: 0.5556 - val_acc: 0.8104
# Epoch 12/50
# 6026/6026 [==============================] - 12s 2ms/step - loss: 0.5074 - acc: 0.8249 - val_loss: 0.5578 - val_acc: 0.7836
# Epoch 13/50
# 6026/6026 [==============================] - 12s 2ms/step - loss: 0.4991 - acc: 0.8216 - val_loss: 0.5412 - val_acc: 0.8045
# Epoch 14/50
# 6026/6026 [==============================] - 12s 2ms/step - loss: 0.4861 - acc: 0.8287 - val_loss: 0.5384 - val_acc: 0.7970
# Epoch 15/50
# 6026/6026 [==============================] - 13s 2ms/step - loss: 0.4671 - acc: 0.8331 - val_loss: 0.5226 - val_acc: 0.8104
# Epoch 16/50
# 6026/6026 [==============================] - 12s 2ms/step - loss: 0.4538 - acc: 0.8392 - val_loss: 0.5350 - val_acc: 0.8060
# Epoch 17/50
# 6026/6026 [==============================] - 12s 2ms/step - loss: 0.4559 - acc: 0.8336 - val_loss: 0.5146 - val_acc: 0.8134
# Epoch 18/50
# 6026/6026 [==============================] - 12s 2ms/step - loss: 0.4451 - acc: 0.8414 - val_loss: 0.5140 - val_acc: 0.8194
# Epoch 19/50
# 6026/6026 [==============================] - 13s 2ms/step - loss: 0.4215 - acc: 0.8493 - val_loss: 0.4949 - val_acc: 0.8134
# Epoch 20/50
# 6026/6026 [==============================] - 13s 2ms/step - loss: 0.4201 - acc: 0.8477 - val_loss: 0.5076 - val_acc: 0.8239
# Epoch 21/50
# 6026/6026 [==============================] - 13s 2ms/step - loss: 0.4065 - acc: 0.8551 - val_loss: 0.5182 - val_acc: 0.8075
# Epoch 22/50
# 6026/6026 [==============================] - 12s 2ms/step - loss: 0.3981 - acc: 0.8530 - val_loss: 0.5010 - val_acc: 0.8060
# Epoch 23/50
# 6026/6026 [==============================] - 14s 2ms/step - loss: 0.3986 - acc: 0.8558 - val_loss: 0.4891 - val_acc: 0.8224
# Epoch 24/50
# 6026/6026 [==============================] - 13s 2ms/step - loss: 0.3873 - acc: 0.8619 - val_loss: 0.4787 - val_acc: 0.8164
# Epoch 25/50
# 6026/6026 [==============================] - 14s 2ms/step - loss: 0.3896 - acc: 0.8568 - val_loss: 0.4740 - val_acc: 0.8284
# Epoch 26/50
# 6026/6026 [==============================] - 14s 2ms/step - loss: 0.3722 - acc: 0.8674 - val_loss: 0.4840 - val_acc: 0.8164
# Epoch 27/50
# 6026/6026 [==============================] - 14s 2ms/step - loss: 0.3705 - acc: 0.8639 - val_loss: 0.5002 - val_acc: 0.8104
# Epoch 28/50
# 6026/6026 [==============================] - 13s 2ms/step - loss: 0.3602 - acc: 0.8654 - val_loss: 0.4894 - val_acc: 0.8149
# Epoch 29/50
# 6026/6026 [==============================] - 14s 2ms/step - loss: 0.3618 - acc: 0.8694 - val_loss: 0.4823 - val_acc: 0.8015
# Epoch 30/50
# 6026/6026 [==============================] - 15s 2ms/step - loss: 0.3523 - acc: 0.8704 - val_loss: 0.4799 - val_acc: 0.8313
# Epoch 31/50
# 6026/6026 [==============================] - 14s 2ms/step - loss: 0.3413 - acc: 0.8740 - val_loss: 0.4931 - val_acc: 0.8209
# Epoch 32/50
# 6026/6026 [==============================] - 14s 2ms/step - loss: 0.3310 - acc: 0.8818 - val_loss: 0.4969 - val_acc: 0.8149
# Epoch 33/50
# 6026/6026 [==============================] - 15s 2ms/step - loss: 0.3333 - acc: 0.8774 - val_loss: 0.4876 - val_acc: 0.8254
# Epoch 34/50
# 6026/6026 [==============================] - 14s 2ms/step - loss: 0.3220 - acc: 0.8808 - val_loss: 0.5162 - val_acc: 0.8015
# Epoch 35/50
# 6026/6026 [==============================] - 14s 2ms/step - loss: 0.3165 - acc: 0.8817 - val_loss: 0.5130 - val_acc: 0.8000

# %%
score = model.evaluate(X_test, y_test, verbose=0)
print('Test loss:', score[0])
print('Test accuracy:', score[1])
# Out:
# Test loss: 0.4699846855414811
# Test accuracy: 0.8373655676841736

# %% [markdown]
# Based on different models and tests, we have learned the word embedding; it seems that the 500k corpus was enough to explain 6k corpus(train data). 83.7% accuracy is supporting that.
#
# Considering the scale gap of 2m corpus from fastText and 500k corpus, 500k was a good basis for learning
